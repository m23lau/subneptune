# %%
import juliet
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pickle
import tqdm
import corner
# Out:
# Warning: no zeus installation found. Will not be able to sample using sampler = 'zeus'.
# Warning: no jax and/or kelp installation found. No kelp phase curves will be able to be used.

# %%
# Open pickle file (which are the outputs of transitspectroscopy)
with open('/media/peng/KINGSTON/_nrs1_v1jw03385001001_toi1130_nrs1_spectrum.pkl', 'rb') as f:
    data = pickle.load(f)

# data is a dict with 7 entries: 
# 1. metadata: Information about instrument and detector, ex. name: NIRSpec, detector: NRS1
# 2. & 3. tso & tso_err: Not sure, just a bunch of zeroes as far as I can see
# 4. traces: Contains times in random order, x, ycorrected, ysmoothed
# 5 spectra: Contains times in increasing order, original + original_err, corrected + corrected_err, wavelength map (a bunch of nans) and wavelengths that the detector measures
# --> IMPORTANT: data['spectra']['corrected'] and corrected_err are each spectroscopic lc for the corresponding wavelength
# 6 & 7. whitelight & whitelight_err: Relative flux for white light curve and its errorbars

# %% [markdown]
# # White Light Curves
#
# Only run this part of the notebook for White Light Curves, otherwise the t, f and ferr variables will override the other t, f, ferr later on.

# %%
# Plot data points
t = data['spectra']['times']
f = data['whitelight']
ferr = data['whitelight_err']

# Scatter data points
plt.errorbar(t, f, yerr = ferr, fmt = '.', alpha = 0.1, color = 'y', label = 'Data before dividing')

# Divide data points by median of first 100 points --> Correction to normalize lightcurve at Relative Flux = 1 before transit
f_med = np.nanmedian(f[:100])
f, ferr = f / f_med, ferr / f_med
plt.errorbar(t, f, yerr = ferr, fmt = '.', alpha = 0.1, color = 'b', label = 'Data after dividing')

plt.title('TOI-1130b NRS1 White Light Curve')
plt.xlabel('Time, [BJD]')
plt.ylabel('Relative Flux')
plt.legend()
plt.show()

# %%
# Define planetary parameters
per = 4.074554           # Period (days)
t0 = 2460770.3450000     # Mid-transit time (BJD)
# rp = 0.0480              # Radius of planet/star (Rp/R*)
b = -0.518               # Impact parameter
a = 13.50                # Semimajor axis (a/R*)
ecc = 0.0052162          # Eccentricity
omega = 141.11           # Argument of periastron (degrees)

# %%
# Define linear regressors
def standard_regressors(x):
    """...
    """
    return x - (np.mean(x) / np.sqrt(np.var(x)))

regressors = np.zeros([len(t), 1])   # Array with len(t) rows, 1 column
regressors[:, 0] = standard_regressors(t)

# %%
# Put into dictionaries
times, fluxes, fluxes_err, linear_regressors, GP_regressors = {}, {}, {}, {}, {}
times['NRS1'], fluxes['NRS1'], fluxes_err['NRS1'] = t, f, ferr
linear_regressors['NRS1'] = regressors
GP_regressors['NRS1'] = regressors


# NRS1 params
params = ['P_p1', 't0_p1', 'a_p1', 'b_p1', 'u1_NRS1', 'u2_NRS1', 'ecc_p1', 'omega_p1', 'p_p1',
          'mdilution_NRS1', 'mflux_NRS1', 'sigma_w_NRS1', 'GP_sigma_NRS1', 'GP_rho_NRS1']

dists = ['fixed', 'normal', 'fixed', 'fixed', 'uniform', 'uniform', 'fixed', 'fixed', 'uniform',
         'fixed', 'normal', 'loguniform', 'loguniform', 'loguniform']

hyperps = [per, [t0, 0.2], a, b, [-3., 3.], [-3., 3.], ecc, omega, [0., 0.2],
           1.0, [0., 0.1], [10., 1000.], [1e-8, 1e-2], [1e-8, 1e2]]

priors = juliet.generate_priors(params, dists, hyperps)   # Same as doing for loop over an empty dict

# %%
# Load dataset and run sampler
dataset = juliet.load(priors = priors, t_lc = times, y_lc = fluxes, yerr_lc = fluxes_err, 
                    GP_regressors_lc = GP_regressors,
                    ld_laws = 'quadratic', out_folder = 'TOI-1130b_fit_nrs1')

results = dataset.fit(sampler = 'dynamic_dynesty', nthreads = 2, verbose = True, n_live_points = 1000)
print('done')    # In case it looks like it's freezing
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Load dataset and run sampler
# ----> 2 dataset = juliet.load(priors = priors, t_lc = times, y_lc = fluxes, yerr_lc = fluxes_err,
#       3                     GP_regressors_lc = GP_regressors,
#       4                     ld_laws = 'quadratic', out_folder = 'TOI-1130b_fit_nrs1')
#       6 results = dataset.fit(sampler = 'dynamic_dynesty', nthreads = 2, verbose = True, n_live_points = 1000)
#       7 print('done')    # In case it looks like it's freezing
#
# File ~/anaconda3/envs/snvenv/lib/python3.10/site-packages/juliet/fit.py:1473, in load.__init__(self, priors, starting_point, input_folder, t_lc, y_lc, yerr_lc, t_rv, y_rv, yerr_rv, GP_regressors_lc, linear_regressors_lc, GP_regressors_rv, linear_regressors_rv, out_folder, lcfilename, rvfilename, GPlceparamfile, GPrveparamfile, LMlceparamfile, LMrveparamfile, lctimedef, rvtimedef, ld_laws, priorfile, lc_n_supersamp, lc_exptime_supersamp, lc_instrument_supersamp, mag_to_flux, verbose, matern_eps, george_hodlr, pickle_encoding, non_linear_functions, extra_loglikelihood)
#    1470 # Finally, generate datadicts, that will save information about the fits, including gaussian_process objects for each instrument that requires it
#    1471 # (including the case of global models):
#    1472 if t_lc is not None:
# -> 1473     self.generate_datadict('lc')
#    1474 if t_rv is not None:
#    1475     self.generate_datadict('rv')
#
# File ~/anaconda3/envs/snvenv/lib/python3.10/site-packages/juliet/fit.py:971, in load.generate_datadict(self, dictype)
#     968 if (GP_regressors is not None) and (instrument in GP_regressors.keys()):
#     970     dictionary[instrument]['GPDetrend'] = True
# --> 971     dictionary[instrument]['noise_model'] = gaussian_process(
#     972         self,
#     973         model_type=dictype,
#     974         instrument=instrument,
#     975         matern_eps=self.matern_eps,
#     976         george_hodlr=self.george_hodlr)
#     977     if not dictionary[instrument]['noise_model'].isInit:
#     978         # Blame the user, although perhaps we could simply solve this as for the global modelling?:
#     979         raise Exception(
#     980             'INPUT ERROR: GP regressors for instrument ' +
#     981             instrument +
#     982             ' use celerite, and are not in ascending or descending order. Please, give the input in those orders --- it will not work othersie.'
#     983         )
#
# File ~/anaconda3/envs/snvenv/lib/python3.10/site-packages/juliet/fit.py:5764, in gaussian_process.__init__(self, data, model_type, instrument, george_hodlr, matern_eps)
#    5762     diff2 = np.count_nonzero(self.X - self.X[idx_sorted[::-1]])
#    5763     if diff1 == 0 or diff2 == 0:
# -> 5764         self.init_GP()
#    5765         self.isInit = True
#    5766 else:
#
# File ~/anaconda3/envs/snvenv/lib/python3.10/site-packages/juliet/fit.py:5315, in gaussian_process.init_GP(self)
#    5312         else:
#    5313             self.GP = george.GP(self.kernel, mean = 0.0, fit_mean = False, white_noise = jitter_term,\
#    5314                                 fit_white_noise = True)
# -> 5315 self.compute_GP()
#
# File ~/anaconda3/envs/snvenv/lib/python3.10/site-packages/juliet/fit.py:5320, in gaussian_process.compute_GP(self, X)
#    5318 if self.yerr is not None:
#    5319     if X is None:
# -> 5320         self.GP.compute(self.X, yerr=self.yerr)
#    5321     else:
#    5322         self.GP.compute(X, yerr=self.yerr)
#
# File ~/anaconda3/envs/snvenv/lib/python3.10/site-packages/celerite/celerite.py:144, in GP.compute(self, t, yerr, check_sorted, A, U, V)
#     142 self._U = np.empty((0, 0)) if U is None else U
#     143 self._V = np.empty((0, 0)) if V is None else V
# --> 144 self.solver.compute(
#     145     self.kernel.jitter,
#     146     alpha_real,
#     147     beta_real,
#     148     alpha_complex_real,
#     149     alpha_complex_imag,
#     150     beta_complex_real,
#     151     beta_complex_imag,
#     152     self._A,
#     153     self._U,
#     154     self._V,
#     155     t,
#     156     self._yerr ** 2,
#     157 )
#     158 self.dirty = False
#
# LinAlgError: failed to factorize or solve matrix

# %%
# From posterior, define best fit and +/- 1 sigma band
transit_model, transit_up68, transit_low68 = results.lc.evaluate('NRS1', return_err = True)

# Bin & scatter data, then plot
xbin, ybin, ybinerr = None, None, None
xbin, ybin, ybinerr = juliet.bin_data(t, f, 20)
plt.errorbar(xbin, ybin, yerr = ybinerr, fmt = '.', color = 'k', alpha = 0.5, ms = 8, zorder = 5, label = 'binned data')
plt.errorbar(dataset.times_lc['NRS1'], dataset.data_lc['NRS1'], yerr = dataset.errors_lc['NRS1'], 
             fmt = '.', alpha = 0.1, zorder = 1, label = 'data')
plt.plot(dataset.times_lc['NRS1'], transit_model, color = 'r', zorder = 10, label = 'fit') 
plt.fill_between(dataset.times_lc['NRS1'], transit_up68, transit_low68, color = 'y', alpha = 0.5, zorder = 5)

plt.title('TOI-1130b NRS1 White Light Curve + Fit')
plt.xlabel('Time [BJD]')
plt.ylabel('Relative flux')
plt.legend()
plt.show()

# %%
# Plot lightcurve relative to mid-transit time
normalized_time = (t - t0) * 24

plt.errorbar(normalized_time, dataset.data_lc['NRS1'], yerr = dataset.errors_lc['NRS1'], 
             fmt = '.', alpha = 0.1, zorder = 1, label = 'data')
plt.plot(normalized_time, transit_model, color = 'r', label = 'fit')

plt.title('TOI-1130b NRS1 WLC (Relative to mid-transit)')
plt.xlabel('Time [hours after transit]')
plt.ylabel('Relative flux')

plt.legend()
plt.show()

# Plot residuals 
resid = f - transit_model
plt.scatter(normalized_time, resid, alpha = 0.1, zorder = 1)
plt.axhline(y = 0, ls = '--', color = 'k', alpha = 0.8, zorder = 10)

plt.title('Residuals')
plt.xlabel('Time [hours after transit]')
plt.ylabel('Relative flux')
plt.show()

# %%
# Create corner plot
list_post = []
names = []
for f in results.posteriors['posterior_samples']:
    if f not in ['unnamed', 'loglike']:
        names.append(f)
        list_post.append(results.posteriors['posterior_samples'][f])
tr = np.array(list_post).T
corner.corner(tr, labels = names, show_titles=True, quantiles=[0.32, 0.5, 0.68])
plt.show()

# %%
# Print Log Evidence
print('Without GP: ~', -3000)
print(results.posteriors['lnZ'])

# %% [markdown]
# # Spectral Light Curves

# %%
spectra = data['spectra']

# There are 2550 times and 1543 wavelengths
t = spectra['times']
wl = spectra['wavelengths']   

# Each spectra['corrected'] is a 2550x1543 array, where columns contain the corresponding spectroscopic light curve in ppm
slc, slc_err = spectra['corrected'], spectra['corrected_err']  

# We can plot corrected spectrum vs wavelength to see something that looks like the stellar spectrum
plt.plot(wl, slc[0])
plt.title('TOI-1130 Stellar Spectrum, NRS1')
plt.xlabel('Wavelength [$\mu$m]')
plt.ylabel('Flux [ppm]')
plt.show()

# To format slc and slc_err to give fluxes at each wavelength, index them along a column
# For example f[i] = slc[:, i] gives the ith spectroscopic light curve corresponding to the ith wavelength
for i in range(0, 1600, 400):
    plt.plot(t, slc[:, i])

plt.title('Random Spectroscopic Light Curves')
plt.xlabel('Time [BJD]')
plt.ylabel('Flux [ppm]')
plt.show()
